# %%
import pandas as pd
import os

# %%
DATA_FINAL_DIR = 'data/'
MODEL_FINAL_DIR = 'models/'
RESULT_FINAL_DIR = 'result/'

# %%
list_model = [
    'dense',
    'cnn',
    'lstm',
    'bilstm',
    'gru',
    'bigru'
]

result = pd.DataFrame()

for model in list_model:
    result_file = os.path.join(RESULT_FINAL_DIR, f'results_{model}.csv')
    if os.path.exists(result_file):
        df = pd.read_csv(result_file)
        df['model'] = model
        result = pd.concat([result, df], ignore_index=True)

# %%
resultr
# Out:
#     model  layer  fold  accuracy  precision    recall  f1_score  \
# 0   dense      1     1  0.848837   0.826087  0.883721  0.853933
# 1   dense      1     2  0.854651   0.821053  0.906977  0.861878
# 2   dense      1     3  0.866279   0.853933  0.883721  0.868571
# 3   dense      1     4  0.880814   0.865922  0.901163  0.883191
# 4   dense      1     5  0.845930   0.802030  0.918605  0.856369
# ..    ...    ...   ...       ...        ...       ...       ...
# 85  bigru      3     1  0.866279   0.850000  0.889535  0.869318
# 86  bigru      3     2  0.843023   0.804124  0.906977  0.852459
# 87  bigru      3     3  0.831395   0.785000  0.912791  0.844086
# 88  bigru      3     4  0.843023   0.804124  0.906977  0.852459
# 89  bigru      3     5  0.857558   0.836066  0.889535  0.861972
#
#           confusion_matrix
# 0   [[140, 32], [20, 152]]
# 1   [[138, 34], [16, 156]]
# 2   [[146, 26], [20, 152]]
# 3   [[148, 24], [17, 155]]
# 4   [[133, 39], [14, 158]]
# ..                     ...
# 85  [[145, 27], [19, 153]]
# 86  [[134, 38], [16, 156]]
# 87  [[129, 43], [15, 157]]
# 88  [[134, 38], [16, 156]]
# 89  [[142, 30], [19, 153]]
#
# [90 rows x 8 columns]

# %%
result.groupby(['model', 'layer']).mean().reset_index()
# Out:
# C:\Users\KEY\AppData\Local\Temp\ipykernel_32868\1802265085.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result.groupby(['model', 'layer']).mean().reset_index()
#      model  layer  fold  accuracy  precision    recall  f1_score
# 0    bigru      1   3.0  0.860465   0.836362  0.896512  0.865324
# 1    bigru      2   3.0  0.853488   0.828427  0.894186  0.859357
# 2    bigru      3   3.0  0.848256   0.815863  0.901163  0.856059
# 3   bilstm      1   3.0  0.837209   0.802417  0.895349  0.846204
# 4   bilstm      2   3.0  0.818023   0.785346  0.875581  0.827952
# 5   bilstm      3   3.0  0.840116   0.809704  0.891860  0.848263
# 6      cnn      1   3.0  0.866860   0.845679  0.897674  0.870824
# 7      cnn      2   3.0  0.855233   0.832802  0.889535  0.860077
# 8      cnn      3   3.0  0.854651   0.829572  0.893023  0.859952
# 9    dense      1   3.0  0.859302   0.833805  0.898837  0.864788
# 10   dense      2   3.0  0.867442   0.847965  0.896512  0.871260
# 11   dense      3   3.0  0.865116   0.842987  0.897674  0.869406
# 12     gru      1   3.0  0.845349   0.818999  0.888372  0.851921
# 13     gru      2   3.0  0.843023   0.822029  0.877907  0.848398
# 14     gru      3   3.0  0.854070   0.834889  0.883721  0.858222
# 15    lstm      1   3.0  0.840698   0.811846  0.888372  0.848072
# 16    lstm      2   3.0  0.841860   0.818693  0.879070  0.847559
# 17    lstm      3   3.0  0.851163   0.829210  0.886047  0.856335

# %%
result.to_csv(os.path.join(RESULT_FINAL_DIR, 'result.csv'), index=False)

# %%
result.to_excel(os.path.join(RESULT_FINAL_DIR, 'result.xlsx'), index=False)

# %%
result.groupby(['model', 'layer']).mean().reset_index().sort_values(by=['f1_score'], ascending=False)
# Out:
# C:\Users\KEY\AppData\Local\Temp\ipykernel_32868\3490075380.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result.groupby(['model', 'layer']).mean().reset_index().sort_values(by=['f1_score'], ascending=False)
#      model  layer  fold  accuracy  precision    recall  f1_score
# 10   dense      2   3.0  0.867442   0.847965  0.896512  0.871260
# 6      cnn      1   3.0  0.866860   0.845679  0.897674  0.870824
# 11   dense      3   3.0  0.865116   0.842987  0.897674  0.869406
# 0    bigru      1   3.0  0.860465   0.836362  0.896512  0.865324
# 9    dense      1   3.0  0.859302   0.833805  0.898837  0.864788
# 7      cnn      2   3.0  0.855233   0.832802  0.889535  0.860077
# 8      cnn      3   3.0  0.854651   0.829572  0.893023  0.859952
# 1    bigru      2   3.0  0.853488   0.828427  0.894186  0.859357
# 14     gru      3   3.0  0.854070   0.834889  0.883721  0.858222
# 17    lstm      3   3.0  0.851163   0.829210  0.886047  0.856335
# 2    bigru      3   3.0  0.848256   0.815863  0.901163  0.856059
# 12     gru      1   3.0  0.845349   0.818999  0.888372  0.851921
# 13     gru      2   3.0  0.843023   0.822029  0.877907  0.848398
# 5   bilstm      3   3.0  0.840116   0.809704  0.891860  0.848263
# 15    lstm      1   3.0  0.840698   0.811846  0.888372  0.848072
# 16    lstm      2   3.0  0.841860   0.818693  0.879070  0.847559
# 3   bilstm      1   3.0  0.837209   0.802417  0.895349  0.846204
# 4   bilstm      2   3.0  0.818023   0.785346  0.875581  0.827952
